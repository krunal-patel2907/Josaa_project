# %% [markdown]
# <a href="https://colab.research.google.com/github/CulenS/JOSAA-Portal/blob/main/JOSAA_Portal_Detail_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_G_F = pd.read_csv('/content/ORCR_G_F.csv')
df_G_F.head()
# Out:
#   Institute                              Academic Program Name  Opening Rank  \
# 0  IIT Bhuv                                  Civil Engineering         10078
# 1  IIT Bhuv  Civil Engineering and M. Tech. in Structural E...         10844
# 2  IIT Bhuv  Civil Engineering and M.Tech in Transportation...         11727
# 3  IIT Bhuv  Civil Engineering and M.Tech. in Environmental...         11349
# 4  IIT Bhuv                   Computer Science and Engineering          2602
#
#    Closing Rank  Year  Round
# 0         10789  2018      1
# 1         10844  2018      1
# 2         11727  2018      1
# 3         11349  2018      1
# 4          3442  2018      1

# %%
df_G_M = pd.read_csv('/content/ORCR_G_M.csv')
df_G_M.head()
# Out:
#   Institute                              Academic Program Name  Opening Rank  \
# 0  IIT Bhuv                                  Civil Engineering          3533
# 1  IIT Bhuv  Civil Engineering and M. Tech. in Structural E...          5408
# 2  IIT Bhuv  Civil Engineering and M.Tech in Transportation...          6078
# 3  IIT Bhuv                   Computer Science and Engineering          1497
# 4  IIT Bhuv                             Electrical Engineering          2933
#
#    Closing Rank  Year  Round
# 0          5947  2016      1
# 1          6561  2016      1
# 2          6579  2016      1
# 3          2665  2016      1
# 4          4241  2016      1

# %%
df_G_F_BT = df_G_F.loc[df_G_F['Academic Program Name'].str.contains('(5)') == False]
df_G_F_BT['Academic Program Name'].unique().shape[0]
# Out:
# <ipython-input-15-45f917cd7ac6>:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_G_F_BT = df_G_F.loc[df_G_F['Academic Program Name'].str.contains('(5)') == False]
# 71

# %%
df_G_F_BT_R1 = df_G_F_BT.loc[df_G_F_BT['Round'] == 1].drop(['Round'], axis = 1)
df_G_F_BT_R1.head()
# Out:
#   Institute                      Academic Program Name  Opening Rank  \
# 0  IIT Bhuv                          Civil Engineering         10078
# 4  IIT Bhuv           Computer Science and Engineering          2602
# 7  IIT Bhuv                     Electrical Engineering          5689
# 8  IIT Bhuv  Electronics and Communication Engineering          3615
# 9  IIT Bhuv                     Mechanical Engineering          8510
#
#    Closing Rank  Year
# 0         10789  2018
# 4          3442  2018
# 7          6178  2018
# 8          5492  2018
# 9          9039  2018

# %%
df_G_F_BT_R1_CR = df_G_F_BT_R1.drop(['Opening Rank'], axis = 1)
df_G_F_BT_R1_CR.head()
# Out:
#   Institute                      Academic Program Name  Closing Rank  Year
# 0  IIT Bhuv                          Civil Engineering         10789  2018
# 4  IIT Bhuv           Computer Science and Engineering          3442  2018
# 7  IIT Bhuv                     Electrical Engineering          6178  2018
# 8  IIT Bhuv  Electronics and Communication Engineering          5492  2018
# 9  IIT Bhuv                     Mechanical Engineering          9039  2018

# %%
df_G_F_BT_R1_CR_Kgp = df_G_F_BT_R1_CR.loc[df_G_F_BT_R1_CR['Institute'] == 'IITKgp']
df_G_F_BT_R1_CR_Kgp.head()
# Out:
#    Institute                      Academic Program Name  Closing Rank  Year
# 57    IITKgp                      Aerospace Engineering          5714  2018
# 59    IITKgp          Agricultural and Food Engineering         10113  2018
# 63    IITKgp  Biotechnology and Biochemical Engineering          7349  2018
# 65    IITKgp                       Chemical Engineering          5536  2018
# 68    IITKgp                          Civil Engineering          7154  2018

# %%
sns.barplot(x = df_G_F_BT_R1_CR_Kgp['Closing Rank'], y = df_G_F_BT_R1_CR_Kgp['Academic Program Name'], hue = df_G_F_BT_R1_CR_Kgp['Year'])
plt.show()

# %%
df_G_F_BT_R5 = df_G_F_BT.loc[df_G_F_BT['Round'] == 5].drop(['Round'], axis = 1)
df_G_F_BT_R5_CR = df_G_F_BT_R5.drop(['Opening Rank'], axis = 1)
df_G_F_BT_R5_CR_Kgp = df_G_F_BT_R5_CR.loc[df_G_F_BT_R5_CR['Institute'] == 'IITKgp']
df_G_F_BT_R5_CR_Kgp.head()
# Out:
#      Institute                      Academic Program Name  Closing Rank  Year
# 1057    IITKgp                      Aerospace Engineering          5714  2018
# 1059    IITKgp          Agricultural and Food Engineering         10113  2018
# 1063    IITKgp  Biotechnology and Biochemical Engineering          7349  2018
# 1065    IITKgp                       Chemical Engineering          5536  2018
# 1068    IITKgp                          Civil Engineering          7179  2018

# %%
sns.barplot(x = df_G_F_BT_R5_CR_Kgp['Closing Rank'], y = df_G_F_BT_R5_CR_Kgp['Academic Program Name'], hue = df_G_F_BT_R5_CR_Kgp['Year'])
plt.show()

# %%
df_G_M_BT = df_G_M.loc[df_G_M['Academic Program Name'].str.contains('(5)') == False]
df_G_M_BT['Academic Program Name'].unique()
# Out:
# <ipython-input-38-d22b3b4fe1ce>:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_G_M_BT = df_G_M.loc[df_G_M['Academic Program Name'].str.contains('(5)') == False]
# array(['Civil Engineering', 'Computer Science and Engineering',
#        'Electrical Engineering',
#        'Electronics and Communication Engineering',
#        'Mechanical Engineering',
#        'Metallurgical and Materials Engineering', 'Aerospace Engineering',
#        'Chemical Engineering', 'Chemistry (B.Sc)', 'Engineering Physics',
#        'Metallurgical Engineering and Materials Science',
#        'Biotechnology and Biochemical Engineering',
#        'Electrical Engineering (Power and Automation)',
#        'Mathematics and Computing',
#        'Production and Industrial Engineering', 'Textile Technology',
#        'Agricultural and Food Engineering',
#        'Electronics and Electrical Communication Engineering',
# ...

# %%
df_G_M_BT_CR = df_G_M_BT.drop(['Opening Rank'], axis = 1)
df_G_M_BT_CR.head()
# Out:
#   Institute                      Academic Program Name  Closing Rank  Year  \
# 0  IIT Bhuv                          Civil Engineering          5947  2016
# 3  IIT Bhuv           Computer Science and Engineering          2665  2016
# 4  IIT Bhuv                     Electrical Engineering          4241  2016
# 5  IIT Bhuv  Electronics and Communication Engineering          3994  2016
# 6  IIT Bhuv                     Mechanical Engineering          4692  2016
#
#    Round
# 0      1
# 3      1
# 4      1
# 5      1
# 6      1

# %%
core = ['Civil Engineering', 'Electrical Engineering', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Electronics and Electrical Communication Engineering', 'Electrical and Electronics Engineering', 'Mining Engineering']
CS = ['Computer Science and Engineering', 'Mathematics and Computing', 'Data Science and Engineering', 'Artificial Intelligence', 'Artificial Intelligence and Data Science', 'Data Science and Artificial Intelligence']

# %%
for branch in core:
  print (branch)
# Out:
# Civil Engineering
# Electrical Engineering
# Electronics and Communication Engineering
# Mechanical Engineering
# Electronics and Electrical Communication Engineering
# Electrical and Electronics Engineering
# Mining Engineering

# %%
for branch in CS:
  print (branch)
# Out:
# Computer Science and Engineering
# Mathematics and Computing
# Data Science and Engineering
# Artificial Intelligence
# Artificial Intelligence and Data Science
# Data Science and Artificial Intelligence

# %%
df_G_M_BT_R5 = df_G_M_BT.loc[df_G_M_BT['Round'] == 5].drop(['Round'], axis = 1)
df_G_M_BT_R5_CR = df_G_M_BT_R5.drop(['Opening Rank'], axis = 1)
df_G_M_BT_R5_CR_Kgp = df_G_M_BT_R5_CR.loc[df_G_M_BT_R5_CR['Institute'] == 'IITKgp']
df_G_M_BT_R5_CR_Kgp_1722 = df_G_M_BT_R5_CR_Kgp.loc[df_G_M_BT_R5_CR['Year'] != 2016]
df_G_M_BT_R5_CR_Kgp_1822 = df_G_M_BT_R5_CR_Kgp_1722.loc[df_G_M_BT_R5_CR['Year'] != 2017]
df_G_M_BT_R5_CR_Kgp_1922 = df_G_M_BT_R5_CR_Kgp_1822.loc[df_G_M_BT_R5_CR['Year'] != 2018]
df_G_M_BT_R5_CR_Kgp_2022 = df_G_M_BT_R5_CR_Kgp_1922.loc[df_G_M_BT_R5_CR['Year'] != 2019]
df_G_M_BT_R5_CR_Kgp_2022.head()
# Out:
#      Institute                      Academic Program Name  Closing Rank  Year
# 7442    IITKgp                      Aerospace Engineering          3967  2020
# 7444    IITKgp          Agricultural and Food Engineering          7539  2020
# 7448    IITKgp  Biotechnology and Biochemical Engineering          6205  2020
# 7450    IITKgp                       Chemical Engineering          3705  2020
# 7453    IITKgp                          Civil Engineering          5423  2020

# %%
sns.barplot(x = df_G_M_BT_R5_CR_Kgp_2022['Closing Rank'], y = df_G_M_BT_R5_CR_Kgp_2022['Academic Program Name'], hue = df_G_M_BT_R5_CR_Kgp_2022['Year'])
plt.show()

# %%
# Clg = df_G_M_BT_R5_CR['Institute'].unique()
Clg = np.array(['IIT Bhuv', 'IITB', 'IIT Mandi', 'IITD', 'IITI', 'IITKgp', 'IITH',
       'IIT Jodh', 'IITK', 'IITM', 'IIT Gnd', 'IIT Patna', 'IITR', 'IIT Ropar', 'IIT BHU', 'IITG', 'IIT Bhilai',
       'IIT Goa', 'IIT Palakkad', 'IIT Tirupati', 'IIT Jammu',
       'IIT Dharwad', 'IIT (ISM) Dhanbad'], dtype=object)
Clg
# Out:
# array(['IIT Bhuv', 'IITB', 'IIT Mandi', 'IITD', 'IITI', 'IITKgp', 'IITH',
#        'IIT Jodh', 'IITK', 'IITM', 'IIT Gnd', 'IIT Patna', 'IITR',
#        'IIT Ropar', 'IIT BHU', 'IITG', 'IIT Bhilai', 'IIT Goa',
#        'IIT Palakkad', 'IIT Tirupati', 'IIT Jammu', 'IIT Dharwad',
#        'IIT (ISM) Dhanbad'], dtype=object)

# %%
for i in range(23):
    df_G_M_BT_R5 = df_G_M_BT.loc[df_G_M_BT['Round'] == 5].drop(['Round'], axis = 1)
    df_G_M_BT_R5_CR = df_G_M_BT_R5.drop(['Opening Rank'], axis = 1)
    df_G_M_BT_R5_CR_clg = df_G_M_BT_R5_CR.loc[df_G_M_BT_R5_CR['Institute'] == Clg[i]]
    df_G_M_BT_R5_CR_clg_1722 = df_G_M_BT_R5_CR_clg.loc[df_G_M_BT_R5_CR['Year'] != 2016]
    df_G_M_BT_R5_CR_clg_1822 = df_G_M_BT_R5_CR_clg_1722.loc[df_G_M_BT_R5_CR['Year'] != 2017]
    df_G_M_BT_R5_CR_clg_1922 = df_G_M_BT_R5_CR_clg_1822.loc[df_G_M_BT_R5_CR['Year'] != 2018]
    df_G_M_BT_R5_CR_clg_2022 = df_G_M_BT_R5_CR_clg_1922.loc[df_G_M_BT_R5_CR['Year'] != 2019]
    df_G_M_BT_R5_CR_clg_2022.head()

    sns.barplot(x = df_G_M_BT_R5_CR_clg_2022['Closing Rank'], y = df_G_M_BT_R5_CR_clg_2022['Academic Program Name'], hue = df_G_M_BT_R5_CR_clg_2022['Year'])
    plt.title(Clg[i])
    plt.show()
    i = i + 1
