# %% [markdown]
# <a href="https://colab.research.google.com/github/CulenS/JOSAA-Portal/blob/main/JOSAA_Portal_Proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
# %matplotlib inline

# %%
df = pd.read_csv('/content/ORCR.csv')
df.head()
# Out:
#    Unnamed: 0                                   Institute  \
# 0           0  Indian Institute of Technology Bhubaneswar
# 1           1  Indian Institute of Technology Bhubaneswar
# 2           2  Indian Institute of Technology Bhubaneswar
# 3           3  Indian Institute of Technology Bhubaneswar
# 4           4  Indian Institute of Technology Bhubaneswar
#
#                                Academic Program Name Quota Seat Type Gender  \
# 0  Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN    NaN
# 1  Civil Engineering (4 Years, Bachelor of Techno...    AI   OBC-NCL    NaN
# 2  Civil Engineering (4 Years, Bachelor of Techno...    AI        SC    NaN
# 3  Civil Engineering (4 Years, Bachelor of Techno...    AI        ST    NaN
# 4  Civil Engineering and M. Tech. in Structural E...    AI      OPEN    NaN
#
#    Opening Rank  Closing Rank  Year  Round
# 0        3533.0        5947.0  2016      1
# 1        1829.0        2213.0  2016      1
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# Institute                 object
# Academic Program Name     object
# Quota                     object
# Seat Type                 object
# Gender                    object
# Opening Rank             float64
# Closing Rank             float64
# Year                       int64
# Round                      int64
# dtype: object

# %%
df = df.drop(['Unnamed: 0', 'Quota'], axis = 1)
df.head()
# Out:
#                                     Institute  \
# 0  Indian Institute of Technology Bhubaneswar
# 1  Indian Institute of Technology Bhubaneswar
# 2  Indian Institute of Technology Bhubaneswar
# 3  Indian Institute of Technology Bhubaneswar
# 4  Indian Institute of Technology Bhubaneswar
#
#                                Academic Program Name Seat Type Gender  \
# 0  Civil Engineering (4 Years, Bachelor of Techno...      OPEN    NaN
# 1  Civil Engineering (4 Years, Bachelor of Techno...   OBC-NCL    NaN
# 2  Civil Engineering (4 Years, Bachelor of Techno...        SC    NaN
# 3  Civil Engineering (4 Years, Bachelor of Techno...        ST    NaN
# 4  Civil Engineering and M. Tech. in Structural E...      OPEN    NaN
#
#    Opening Rank  Closing Rank  Year  Round
# 0        3533.0        5947.0  2016      1
# 1        1829.0        2213.0  2016      1
# 2         663.0        1023.0  2016      1
# 3         331.0         357.0  2016      1
# 4        5408.0        6561.0  2016      1

# %%
df.shape
# Out:
# (83847, 8)

# %%
df.isnull().sum()
# Out:
# Institute                    0
# Academic Program Name        0
# Seat Type                    0
# Gender                   15285
# Opening Rank                 0
# Closing Rank                 0
# Year                         0
# Round                        0
# dtype: int64

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
df.head()
# Out:
#                                     Institute  \
# 0  Indian Institute of Technology Bhubaneswar
# 1  Indian Institute of Technology Bhubaneswar
# 2  Indian Institute of Technology Bhubaneswar
# 3  Indian Institute of Technology Bhubaneswar
# 4  Indian Institute of Technology Bhubaneswar
#
#                                Academic Program Name Seat Type Gender  \
# 0  Civil Engineering (4 Years, Bachelor of Techno...      OPEN    NaN
# 1  Civil Engineering (4 Years, Bachelor of Techno...   OBC-NCL    NaN
# 2  Civil Engineering (4 Years, Bachelor of Techno...        SC    NaN
# 3  Civil Engineering (4 Years, Bachelor of Techno...        ST    NaN
# 4  Civil Engineering and M. Tech. in Structural E...      OPEN    NaN
#
#    Opening Rank  Closing Rank  Year  Round
# 0        3533.0        5947.0  2016      1
# 1        1829.0        2213.0  2016      1
# 2         663.0        1023.0  2016      1
# 3         331.0         357.0  2016      1
# 4        5408.0        6561.0  2016      1

# %%
df['Opening Rank'] = df['Opening Rank'].astype(int)
df['Closing Rank'] = df['Closing Rank'].astype(int)
df.head()
# Out:
#                                     Institute  \
# 0  Indian Institute of Technology Bhubaneswar
# 1  Indian Institute of Technology Bhubaneswar
# 2  Indian Institute of Technology Bhubaneswar
# 3  Indian Institute of Technology Bhubaneswar
# 4  Indian Institute of Technology Bhubaneswar
#
#                                Academic Program Name Seat Type Gender  \
# 0  Civil Engineering (4 Years, Bachelor of Techno...      OPEN    NaN
# 1  Civil Engineering (4 Years, Bachelor of Techno...   OBC-NCL    NaN
# 2  Civil Engineering (4 Years, Bachelor of Techno...        SC    NaN
# 3  Civil Engineering (4 Years, Bachelor of Techno...        ST    NaN
# 4  Civil Engineering and M. Tech. in Structural E...      OPEN    NaN
#
#    Opening Rank  Closing Rank  Year  Round
# 0          3533          5947  2016      1
# 1          1829          2213  2016      1
# 2           663          1023  2016      1
# 3           331           357  2016      1
# 4          5408          6561  2016      1

# %%
df_G = df.loc[df['Seat Type'] == "OPEN"]
df_G = df_G.drop(['Seat Type'], axis = 1)
df_G.head()
# Out:
#                                      Institute  \
# 0   Indian Institute of Technology Bhubaneswar
# 4   Indian Institute of Technology Bhubaneswar
# 8   Indian Institute of Technology Bhubaneswar
# 11  Indian Institute of Technology Bhubaneswar
# 17  Indian Institute of Technology Bhubaneswar
#
#                                 Academic Program Name Gender  Opening Rank  \
# 0   Civil Engineering (4 Years, Bachelor of Techno...    NaN          3533
# 4   Civil Engineering and M. Tech. in Structural E...    NaN          5408
# 8   Civil Engineering and M.Tech in Transportation...    NaN          6078
# 11  Computer Science and Engineering (4 Years, Bac...    NaN          1497
# 17  Electrical Engineering (4 Years, Bachelor of T...    NaN          2933
#
#     Closing Rank  Year  Round
# 0           5947  2016      1
# 4           6561  2016      1
# 8           6579  2016      1
# 11          2665  2016      1
# 17          4241  2016      1

# %%
df_G.shape
# Out:
# (18625, 7)

# %%
df_G_R1 = df_G.loc[df_G['Round'] == 1].drop(['Round'], axis = 1)
df_G_R1.head()
# Out:
#                                      Institute  \
# 0   Indian Institute of Technology Bhubaneswar
# 4   Indian Institute of Technology Bhubaneswar
# 8   Indian Institute of Technology Bhubaneswar
# 11  Indian Institute of Technology Bhubaneswar
# 17  Indian Institute of Technology Bhubaneswar
#
#                                 Academic Program Name Gender  Opening Rank  \
# 0   Civil Engineering (4 Years, Bachelor of Techno...    NaN          3533
# 4   Civil Engineering and M. Tech. in Structural E...    NaN          5408
# 8   Civil Engineering and M.Tech in Transportation...    NaN          6078
# 11  Computer Science and Engineering (4 Years, Bac...    NaN          1497
# 17  Electrical Engineering (4 Years, Bachelor of T...    NaN          2933
#
#     Closing Rank  Year
# 0           5947  2016
# 4           6561  2016
# 8           6579  2016
# 11          2665  2016
# 17          4241  2016

# %%
df_G_R1_OR = df_G_R1.drop(['Closing Rank'], axis = 1)
df_G_R1_OR.head()
# Out:
#                                      Institute  \
# 0   Indian Institute of Technology Bhubaneswar
# 4   Indian Institute of Technology Bhubaneswar
# 8   Indian Institute of Technology Bhubaneswar
# 11  Indian Institute of Technology Bhubaneswar
# 17  Indian Institute of Technology Bhubaneswar
#
#                                 Academic Program Name Gender  Opening Rank  \
# 0   Civil Engineering (4 Years, Bachelor of Techno...    NaN          3533
# 4   Civil Engineering and M. Tech. in Structural E...    NaN          5408
# 8   Civil Engineering and M.Tech in Transportation...    NaN          6078
# 11  Computer Science and Engineering (4 Years, Bac...    NaN          1497
# 17  Electrical Engineering (4 Years, Bachelor of T...    NaN          2933
#
#     Year
# 0   2016
# 4   2016
# 8   2016
# 11  2016
# 17  2016

# %%
x0 = df_G_R1_OR['Opening Rank'].loc[df_G_R1_OR['Institute'] == "Indian Institute of Technology Bhubaneswar"]
y0 = df_G_R1_OR['Academic Program Name'].loc[df_G_R1_OR['Institute'] == "Indian Institute of Technology Bhubaneswar"]
hue0 = df_G_R1_OR['Year'].loc[df_G_R1_OR['Institute'] == "Indian Institute of Technology Bhubaneswar"]
sns.barplot(x = x0, y = y0, hue = hue0)
plt.show()

# %%
x1 = df_G_R1_OR['Institute'].loc[df_G_R1_OR['Academic Program Name'] == "Computer Science and Engineering (4 Years, Bachelor of Technology)"]
y1 = df_G_R1_OR['Opening Rank'].loc[df_G_R1_OR['Academic Program Name'] == "Computer Science and Engineering (4 Years, Bachelor of Technology)"]
hue1 = df_G_R1_OR['Year'].loc[df_G_R1_OR['Academic Program Name'] == "Computer Science and Engineering (4 Years, Bachelor of Technology)"]

# %%
sns.scatterplot(y = x1, x = y1, hue = hue1)
plt.show()

# %%
df_G_R1_OR.head()
# Out:
#                                      Institute  \
# 0   Indian Institute of Technology Bhubaneswar
# 4   Indian Institute of Technology Bhubaneswar
# 8   Indian Institute of Technology Bhubaneswar
# 11  Indian Institute of Technology Bhubaneswar
# 17  Indian Institute of Technology Bhubaneswar
#
#                                 Academic Program Name Gender  Opening Rank  \
# 0   Civil Engineering (4 Years, Bachelor of Techno...    NaN          3533
# 4   Civil Engineering and M. Tech. in Structural E...    NaN          5408
# 8   Civil Engineering and M.Tech in Transportation...    NaN          6078
# 11  Computer Science and Engineering (4 Years, Bac...    NaN          1497
# 17  Electrical Engineering (4 Years, Bachelor of T...    NaN          2933
#
#     Year
# 0   2016
# 4   2016
# 8   2016
# 11  2016
# 17  2016

# %%
df_G_R1_OR['Institute'] = df_G_R1_OR['Institute'].str.replace('Indian Institute of Technology', 'IIT')
df_G_R1_OR.head()
# Out:
#           Institute                              Academic Program Name Gender  \
# 0   IIT Bhubaneswar  Civil Engineering (4 Years, Bachelor of Techno...    NaN
# 4   IIT Bhubaneswar  Civil Engineering and M. Tech. in Structural E...    NaN
# 8   IIT Bhubaneswar  Civil Engineering and M.Tech in Transportation...    NaN
# 11  IIT Bhubaneswar  Computer Science and Engineering (4 Years, Bac...    NaN
# 17  IIT Bhubaneswar  Electrical Engineering (4 Years, Bachelor of T...    NaN
#
#     Opening Rank  Year
# 0           3533  2016
# 4           5408  2016
# 8           6078  2016
# 11          1497  2016
# 17          2933  2016

# %%
df_G_R1_OR['Academic Program Name'] = df_G_R1_OR['Academic Program Name'].str.replace(' Years, Bachelor of Technology', '')
df_G_R1_OR['Academic Program Name'] = df_G_R1_OR['Academic Program Name'].str.replace(' Years, Bachelor and Master of Technology', '')
df_G_R1_OR.head()
# Out:
#           Institute                              Academic Program Name Gender  \
# 0   IIT Bhubaneswar                              Civil Engineering (4)    NaN
# 4   IIT Bhubaneswar  Civil Engineering and M. Tech. in Structural E...    NaN
# 8   IIT Bhubaneswar  Civil Engineering and M.Tech in Transportation...    NaN
# 11  IIT Bhubaneswar               Computer Science and Engineering (4)    NaN
# 17  IIT Bhubaneswar                         Electrical Engineering (4)    NaN
#
#     Opening Rank  Year
# 0           3533  2016
# 4           5408  2016
# 8           6078  2016
# 11          1497  2016
# 17          2933  2016

# %%
df_G_R1_OR['Academic Program Name'] = df_G_R1_OR['Academic Program Name'].str.replace('(', '')
df_G_R1_OR.head()
# Out:
# <ipython-input-19-61ca1e3d6515>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_G_R1_OR['Academic Program Name'] = df_G_R1_OR['Academic Program Name'].str.replace('(', '')
#           Institute                              Academic Program Name Gender  \
# 0   IIT Bhubaneswar                               Civil Engineering 4)    NaN
# 4   IIT Bhubaneswar  Civil Engineering and M. Tech. in Structural E...    NaN
# 8   IIT Bhubaneswar  Civil Engineering and M.Tech in Transportation...    NaN
# 11  IIT Bhubaneswar                Computer Science and Engineering 4)    NaN
# 17  IIT Bhubaneswar                          Electrical Engineering 4)    NaN
#
#     Opening Rank  Year
# 0           3533  2016
# 4           5408  2016
# 8           6078  2016
# 11          1497  2016
# 17          2933  2016

# %%
#df_G_R1_OR.to_csv(r'D:\ORCR1.csv')

# %%
df_G_R1_OR['Academic Program Name'] = df_G_R1_OR['Academic Program Name'].str.replace('4', '(4)')
df_G_R1_OR.head()
# Out:
#           Institute                              Academic Program Name Gender  \
# 0   IIT Bhubaneswar                              Civil Engineering (4)    NaN
# 4   IIT Bhubaneswar  Civil Engineering and M. Tech. in Structural E...    NaN
# 8   IIT Bhubaneswar  Civil Engineering and M.Tech in Transportation...    NaN
# 11  IIT Bhubaneswar               Computer Science and Engineering (4)    NaN
# 17  IIT Bhubaneswar                         Electrical Engineering (4)    NaN
#
#     Opening Rank  Year
# 0           3533  2016
# 4           5408  2016
# 8           6078  2016
# 11          1497  2016
# 17          2933  2016

# %%
df_G_R1_OR = df_G_R1_OR.loc[df_G_R1_OR['Academic Program Name'].str.contains('(4)')]
df_G_R1_OR['Academic Program Name'] = df_G_R1_OR['Academic Program Name'].str.replace('(4)', '')
df_G_R1_OR.head()
# Out:
# <ipython-input-25-b8fd8e879277>:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_G_R1_OR = df_G_R1_OR.loc[df_G_R1_OR['Academic Program Name'].str.contains('(4)')]
# <ipython-input-25-b8fd8e879277>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_G_R1_OR['Academic Program Name'] = df_G_R1_OR['Academic Program Name'].str.replace('(4)', '')
# <ipython-input-25-b8fd8e879277>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_G_R1_OR['Academic Program Name'] = df_G_R1_OR['Academic Program Name'].str.replace('(4)', '')
# ...

# %%
df_G_R1_OR['Academic Program Name'] = df_G_R1_OR['Academic Program Name'].str.replace(')', '')
df_G_R1_OR.head()
# Out:
# <ipython-input-27-957ca64003d5>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_G_R1_OR['Academic Program Name'] = df_G_R1_OR['Academic Program Name'].str.replace(')', '')
#           Institute                       Academic Program Name Gender  \
# 0   IIT Bhubaneswar                          Civil Engineering     NaN
# 11  IIT Bhubaneswar           Computer Science and Engineering     NaN
# 17  IIT Bhubaneswar                     Electrical Engineering     NaN
# 21  IIT Bhubaneswar  Electronics and Communication Engineering     NaN
# 26  IIT Bhubaneswar                     Mechanical Engineering     NaN
#
#     Opening Rank  Year
# 0           3533  2016
# 11          1497  2016
# 17          2933  2016
# 21          2529  2016
# 26          3372  2016

# %%
df_G_R1_OR.head()
# Out:
#    level_0        Institute                       Academic Program Name  \
# 0        0  IIT Bhubaneswar                          Civil Engineering
# 1        1  IIT Bhubaneswar           Computer Science and Engineering
# 2        2  IIT Bhubaneswar                     Electrical Engineering
# 3        3  IIT Bhubaneswar  Electronics and Communication Engineering
# 4        4  IIT Bhubaneswar                     Mechanical Engineering
#
#   Gender  Opening Rank  Year
# 0    NaN          3533  2016
# 1    NaN          1497  2016
# 2    NaN          2933  2016
# 3    NaN          2529  2016
# 4    NaN          3372  2016

# %%
df_G_R1_OR['Year'].value_counts()
# Out:
# 2022    424
# 2021    400
# 2020    370
# 2018    342
# 2017    166
# 2016    162
# Name: Year, dtype: int64

# %%
df_G_R1_OR['Gender'].unique()
# Out:
# array([nan, 'Gender-Neutral', 'Female-only (including Supernumerary)'],
#       dtype=object)

# %%
df_G_R1_OR_M = df_G_R1_OR.loc[df_G_R1_OR['Gender'] != "Female-only (including Supernumerary)"]
df_G_R1_OR_M
# Out:
#       level_0        Institute                       Academic Program Name  \
# 0           0  IIT Bhubaneswar                          Civil Engineering
# 1           1  IIT Bhubaneswar           Computer Science and Engineering
# 2           2  IIT Bhubaneswar                     Electrical Engineering
# 3           3  IIT Bhubaneswar  Electronics and Communication Engineering
# 4           4  IIT Bhubaneswar                     Mechanical Engineering
# ...       ...              ...                                         ...
# 1854     1854      IIT Dharwad           Computer Science and Engineering
# 1856     1856      IIT Dharwad                     Electrical Engineering
# 1858     1858      IIT Dharwad                        Engineering Physics
# 1860     1860      IIT Dharwad                  Mathematics and Computing
# 1862     1862      IIT Dharwad                     Mechanical Engineering
#
#               Gender  Opening Rank  Year
# ...

# %%
df_G_R1_OR_M = df_G_R1_OR_M.drop(['Gender'], axis = 1)
df_G_R1_OR_M.head()
# Out:
#    level_0        Institute                       Academic Program Name  \
# 0        0  IIT Bhubaneswar                          Civil Engineering
# 1        1  IIT Bhubaneswar           Computer Science and Engineering
# 2        2  IIT Bhubaneswar                     Electrical Engineering
# 3        3  IIT Bhubaneswar  Electronics and Communication Engineering
# 4        4  IIT Bhubaneswar                     Mechanical Engineering
#
#    Opening Rank  Year
# 0          3533  2016
# 1          1497  2016
# 2          2933  2016
# 3          2529  2016
# 4          3372  2016

# %%
df_G_R1_OR_M['Institute'].value_counts()
# Out:
# IIT Kharagpur                     102
# IIT Kanpur                         80
# IIT Delhi                          74
# IIT Hyderabad                      66
# IIT Roorkee                        65
# IIT Bombay                         64
# IIT Guwahati                       63
# IIT (ISM) Dhanbad                  62
# IIT (BHU) Varanasi                 60
# IIT Madras                         54
# IIT Patna                          39
# IIT Ropar                          37
# IIT Jodhpur                        36
# IIT Gandhinagar                    36
# IIT Bhubaneswar                    36
# IIT Indore                         30
# IIT Mandi                          30
# IIT Jammu                          30
# IIT Tirupati                       28
# IIT Palakkad                       25
# IIT Dharwad                        23
# IIT Bhilai                         22
# IIT Goa                            21
# Indian School of Mines Dhanbad     13
# Name: Institute, dtype: int64

# %%
df_G_R1_OR_M['Institute'] = df_G_R1_OR_M['Institute'].str.replace('Indian School of Mines', 'ISM')
df_G_R1_OR_M['Institute'].value_counts()
# Out:
# IIT Kharagpur         102
# IIT Kanpur             80
# IIT Delhi              74
# IIT Hyderabad          66
# IIT Roorkee            65
# IIT Bombay             64
# IIT Guwahati           63
# IIT (ISM) Dhanbad      62
# IIT (BHU) Varanasi     60
# IIT Madras             54
# IIT Patna              39
# IIT Ropar              37
# IIT Jodhpur            36
# IIT Gandhinagar        36
# IIT Bhubaneswar        36
# IIT Indore             30
# IIT Mandi              30
# IIT Jammu              30
# IIT Tirupati           28
# IIT Palakkad           25
# IIT Dharwad            23
# IIT Bhilai             22
# IIT Goa                21
# ISM Dhanbad            13
# Name: Institute, dtype: int64

# %%
df_G_R1_OR_M
# Out:
#       level_0        Institute                       Academic Program Name  \
# 0           0  IIT Bhubaneswar                          Civil Engineering
# 1           1  IIT Bhubaneswar           Computer Science and Engineering
# 2           2  IIT Bhubaneswar                     Electrical Engineering
# 3           3  IIT Bhubaneswar  Electronics and Communication Engineering
# 4           4  IIT Bhubaneswar                     Mechanical Engineering
# ...       ...              ...                                         ...
# 1854     1854      IIT Dharwad           Computer Science and Engineering
# 1856     1856      IIT Dharwad                     Electrical Engineering
# 1858     1858      IIT Dharwad                        Engineering Physics
# 1860     1860      IIT Dharwad                  Mathematics and Computing
# 1862     1862      IIT Dharwad                     Mechanical Engineering
#
#       Opening Rank  Year
# 0             3533  2016
# 1             1497  2016
# ...

# %%
y3 = df_G_R1_OR_M['Year']
x3 = np.zeros(23)
for i in y3:
  x3[i - 2016] = df_G_R1_OR_M['Opening Rank'].loc[df_G_R1_OR_M['Academic Program Name'] == "Computer Science and Engineering "].loc[df_G_R1_OR_M['Year'] == i]
# Out:
#      level_0           Institute              Academic Program Name  \
# 1          1     IIT Bhubaneswar  Computer Science and Engineering
# 10        10          IIT Bombay  Computer Science and Engineering
# 16        16           IIT Mandi  Computer Science and Engineering
# 22        22           IIT Delhi  Computer Science and Engineering
# 31        31          IIT Indore  Computer Science and Engineering
# 40        40       IIT Kharagpur  Computer Science and Engineering
# 52        52       IIT Hyderabad  Computer Science and Engineering
# 58        58         IIT Jodhpur  Computer Science and Engineering
# 66        66          IIT Kanpur  Computer Science and Engineering
# 77        77          IIT Madras  Computer Science and Engineering
# 85        85     IIT Gandhinagar  Computer Science and Engineering
# 91        91           IIT Patna  Computer Science and Engineering
# 97        97         IIT Roorkee  Computer Science and Engineering
# ...

# %%
df_G_R1_OR_M_CSE = df_G_R1_OR_M.loc[df_G_R1_OR_M['Academic Program Name'] == "Computer Science and Engineering "].drop(['Academic Program Name'], axis = 1)
# df_G_R1_OR_M_CSE
hue4 = df_G_R1_OR_M_CSE['Year']
x4 = df_G_R1_OR_M_CSE['Institute']
y4 = df_G_R1_OR_M_CSE['Opening Rank']
sns.barplot(x = y4, y = x4, hue = hue4)
plt.show()

# %%
df_G_R1_OR_M_CSE = df_G_R1_OR_M.loc[df_G_R1_OR_M['Academic Program Name'] == "Computer Science and Engineering "].drop(['Academic Program Name'], axis = 1)
# df_G_R1_OR_M_CSE
hue5 = np.array([2020, 2021, 2022])
x5i = df_G_R1_OR_M_CSE['Institute'].loc[df_G_R1_OR_M_CSE['Year'] == 2020]
x5ii = df_G_R1_OR_M_CSE['Institute'].loc[df_G_R1_OR_M_CSE['Year'] == 2021]
x5iii = df_G_R1_OR_M_CSE['Institute'].loc[df_G_R1_OR_M_CSE['Year'] == 2022]
x5 = x5i + x5ii + x5iii
y5i = df_G_R1_OR_M_CSE['Opening Rank'].loc[df_G_R1_OR_M_CSE['Year'] == 2020]
y5ii = df_G_R1_OR_M_CSE['Opening Rank'].loc[df_G_R1_OR_M_CSE['Year'] == 2021]
y5iii = df_G_R1_OR_M_CSE['Opening Rank'].loc[df_G_R1_OR_M_CSE['Year'] == 2022]
y5 = y5i + y5ii + y5iii
sns.barplot(x = y5, y = x5, hue = hue5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-487469ac6082> in <cell line: 12>()
#      10 y5iii = df_G_R1_OR_M_CSE['Opening Rank'].loc[df_G_R1_OR_M_CSE['Year'] == 2022]
#      11 y5 = y5i + y5ii + y5iii
# ---> 12 sns.barplot(x = y5, y = x5)
#      13 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2753         estimator = "size"
#    2754
# -> 2755     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                           estimator, errorbar, n_boot, units, seed,
#    2757                           orient, color, palette, saturation,
#
# ...
